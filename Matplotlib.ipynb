# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1, 2, 3, 4, 5]
# y = [1, 4, 9, 16 ,25]
y = np.array(x) ** 2
plt.plot(y)

# %%
y
# Out:
# array([ 1,  4,  9, 16, 25])

# %%
x = [1, 2, 3, 4, 5]
# y = [1, 4, 9, 16 ,25]
y = np.array(x) ** 2
plt.plot(x, y)

# %%
x = np.linspace(-10, 10, 20)
z = 1 / (1 + np.exp(-x))
plt.plot(x, z, 'g--', linewidth=5)

# %%
plt.plot(x, z,
         color='red',
         lw=3,
         ls='--',
         marker='o',
         markersize=7,
         markerfacecolor='yellow',
         markeredgecolor='blue',
         markeredgewidth=2,
         alpha=0.4)

# %%
df = pd.DataFrame({'aa': [1, 2, 3, 4, 5, 6],
                   'bb': [10, 15, 40, 100, 200, 400]})

# %%
plt.plot('aa', 'bb', data=df)

# %%
plt.plot(x, z, label='sigmoid')
plt.plot(x, z*2, label='sigmoid*2')
plt.xlabel('x')
plt.ylabel('y')
plt.title('sigmoid(X)')
plt.legend(loc=4)
plt.xticks([1, 2, 3],rotation=20)
plt.yticks([0, 0.5, 1, 1.5, 2], rotation=20)
# Out:
# ([<matplotlib.axis.YTick at 0x7f58b2564410>,
#   <matplotlib.axis.YTick at 0x7f58b28b1690>,
#   <matplotlib.axis.YTick at 0x7f58b25b5c50>,
#   <matplotlib.axis.YTick at 0x7f58b2511f10>,
#   <matplotlib.axis.YTick at 0x7f58b251a590>],
#  <a list of 5 Text yticklabel objects>)

# %%
# csvファイルを読み込み
df = pd.read_csv('dataset/tmdb_5000_movies.csv')
# release_dateがNaNレコードをフィルタアウト
df = df[~df['release_date'].isna()]
# year 項目作成
df['year'] = df['release_date'].apply(lambda x: int(x[:4]))

# %%
plt.plot(df.groupby('year').count()['id'])
plt.xlabel('year')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
df = df[df['revenue']!=0]
plt.plot(df.groupby('year').median()['revenue'], label='median')
plt.plot(df.groupby('year').mean()['revenue'], label='mean')
plt.plot(df.groupby('year')['revenue'].max(), label='max')
plt.legend()

# %%
x = np.linspace(-10, 10, 100)
plt.subplot(1, 2, 1)
plt.plot(x, x**2)

plt.subplot(1, 2, 2)
plt.plot(x, x**3)

# %%
plt.plot(x, x**3)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

ax1.plot(x, x**2)
ax2.plot(x, x**3)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x, x**2)
axes[1].plot(x, x**3)
fig.tight_layout()

# %%
fig, axes = plt.subplots(2, 2)
axes[0, 0].plot(x, x**2)
axes[0, 1].plot(x, x**3)
axes[1, 0].plot(x, x**4)
axes[1, 1].plot(x, x**5)
fig.tight_layout()

# %%
fig, axes = plt.subplots()
axes.plot(x, x**2)

# %%
fig, axes = plt.subplots(1, 2)
axes[0].plot(x, x**2, label='x**2')
axes[1].plot(x, x**3)
axes[0].set_xlabel('xlabel1')
axes[0].set_ylabel('ylabel1')
axes[0].set_title('title1')
axes[0].legend()
axes[1].axis('off')
# Out:
# (-11.0, 11.0, -1100.0, 1100.0)

# %%
df = pd.read_csv('dataset/tmdb_5000_movies.csv')

# %%
plt.scatter(df['revenue'], df['budget'], alpha=0.2)

# %%
df = df[(df['revenue'] != 0) & (df['budget'] != 0)]
lang_group_df = df.groupby('original_language').mean()[['budget', 'revenue', 'vote_count']]
c = np.arange(len(lang_group_df))
plt.scatter('revenue', 'budget', s='vote_count', c=c, data=lang_group_df)
for idx, row in lang_group_df.iterrows():
    plt.annotate(idx, (row['revenue'], row['budget']))

# %%
df = pd.read_csv('dataset/tmdb_5000_movies.csv')
plt.hist(df['vote_average'], bins=50)
plt.show()

# %%
fig, axes = plt.subplots()
df = df[(df['revenue'] != 0) & (df['budget'] !=0)]
df['profit'] = df.apply(lambda row: row['revenue'] - row['budget'], axis=1)
logbins = np.logspace(4, np.log10(df['profit'].max()), 100)
axes.hist(df['profit'], bins=logbins)
axes.set_xscale('log')
plt.show()

# %%
df = pd.DataFrame({'categorical': ['A', 'B', 'C'], 'val': [10, 30, 20]})

# %%
plt.bar(df['categorical'], df['val'])
# Out:
# <BarContainer object of 3 artists>

# %%
df.plot('categorical', 'val', kind='bar', rot=0)

# %%
df = pd.read_csv('dataset/tmdb_5000_movies.csv')
df['original_language'].value_counts().plot(kind='bar')

# %%
df = pd.read_csv('dataset/tmdb_5000_movies.csv')
plt.boxplot(df['vote_average'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f58aacc3b90>,
#   <matplotlib.lines.Line2D at 0x7f58aacc32d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f58aacbef90>,
#   <matplotlib.lines.Line2D at 0x7f58aacbe2d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f58aaccdd90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f58aacbe310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f58aacb9910>],
#  'means': []}

# %%
x = np.linspace(-3, 3, 10)
plt.figure(figsize=(10, 5))
plt.plot(x, x**2)

# %%
fig, axes = plt.subplots(figsize=(10, 5))
axes.plot(x, x**2)

# %%
df = pd.read_csv('dataset/tmdb_5000_movies.csv')
plt.scatter('runtime', 'budget', data=df, alpha=0.2)
plt.xlabel('runtime')
plt.ylabel('budget')
plt.savefig('runtime_budget_scatter.png')

# %%
fig, axes = plt.subplots(2, 1, figsize=(10, 3))
x = np.linspace(-3, 3, 100)
axes[0].set_title('cosine')
axes[0].plot(x, np.cos(x))
axes[1].set_title('sine')
axes[1].plot(x, np.sin(x))
fig.tight_layout()
fig.savefig('cosine_sine_png')

# %%
from matplotlib.backends.backend_pdf import PdfPages

pdf = PdfPages('pdf_files.pdf')
fig, axes = plt.subplots()
axes.plot(x, x**2)
pdf.savefig(fig)
pdf.close()

# %%
pdf = PdfPages('savemultifig_sample.pdf')
for i in range(10):
    fig, axes = plt.subplots()
    axes.plot(x, x**i)
    axes.set_title('x^{}'.format(i))
    pdf.savefig(fig)
pdf.close()
