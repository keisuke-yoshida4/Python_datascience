# %%
# %load_ext autoreload
# %autoreload 2
from glob import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
glob('*')
# Out:
# ['Matplotlib.ipynb',
#  'NumPy.ipynb',
#  'OpenCV.ipynb',
#  'Pandas.ipynb',
#  'Pythonの基本.ipynb',
#  'README.md',
#  'Seaborn.ipynb',
#  'bimodal_sample.png',
#  'cosine_sine_png.png',
#  'cropped_lenna.png',
#  'dataset',
#  'lenna.png',
#  'pdf_files.pdf',
#  'public-covid-data',
#  'runtime_budget_scatter.png',
#  'sample_dict.npy',
#  'sample_ndarray.npy',
#  'saved_seaborn.png',
#  'savemultifig_sample.pdf',
#  'text_pic.jpg',
#  'その他.ipynb']

# %%
glob('*.png')
# Out:
# ['bimodal_sample.png',
#  'cosine_sine_png.png',
#  'cropped_lenna.png',
#  'lenna.png',
#  'runtime_budget_scatter.png',
#  'saved_seaborn.png']

# %%
glob('public-covid-data/*/*')
# Out:
# ['public-covid-data/rp_im/1.nii.gz',
#  'public-covid-data/rp_im/2.nii.gz',
#  'public-covid-data/rp_im/3.nii.gz',
#  'public-covid-data/rp_im/4.nii.gz',
#  'public-covid-data/rp_im/5.nii.gz',
#  'public-covid-data/rp_im/6.nii.gz',
#  'public-covid-data/rp_im/7.nii.gz',
#  'public-covid-data/rp_im/8.nii.gz',
#  'public-covid-data/rp_im/9.nii.gz',
#  'public-covid-data/rp_msk/1.nii.gz',
#  'public-covid-data/rp_msk/2.nii.gz',
#  'public-covid-data/rp_msk/3.nii.gz',
#  'public-covid-data/rp_msk/4.nii.gz',
#  'public-covid-data/rp_msk/5.nii.gz',
#  'public-covid-data/rp_msk/6.nii.gz',
#  'public-covid-data/rp_msk/7.nii.gz',
#  'public-covid-data/rp_msk/8.nii.gz',
#  'public-covid-data/rp_msk/9.nii.gz']

# %%
glob('public-covid-data/rp_im/[5-9]*')
# Out:
# ['public-covid-data/rp_im/5.nii.gz',
#  'public-covid-data/rp_im/6.nii.gz',
#  'public-covid-data/rp_im/7.nii.gz',
#  'public-covid-data/rp_im/8.nii.gz',
#  'public-covid-data/rp_im/9.nii.gz']

# %%
import os
from pathlib import Path

# %%
p = Path('public-covid-data/')

# %%
p_i = p.iterdir()

# %%
p_i_ = next(p_i)

# %%
p
# Out:
# PosixPath('public-covid-data')

# %%
p_i_
# Out:
# PosixPath('public-covid-data/.ipynb_checkpoints')

# %%
p_i_i = p_i_.iterdir()

# %%
p = Path('public-covid-data/')
new_folder_name = 'new_folder'
new_folder_path = os.path.join(p, new_folder_name)
new_folder_path
# Out:
# 'public-covid-data/new_folder'

# %%
os.path.exists(new_folder_path)
# Out:
# True

# %%
if not os.path.exists(new_folder_path):
    os.makedirs(new_folder_path)

# %%
from tqdm import tqdm

# %%
tqdm()
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
import time
sum_ = 0
before = time.time()
for i in tqdm(range(int(1e7))):
    sum_ += 1
print(sum_)
after = time.time()
print('it took {}'.format(after - before))
# Out:
#   0%|          | 0/10000000 [00:00<?, ?it/s]
#
#   1%|          | 115223/10000000 [00:00<00:08, 1152225.60it/s]
#
#   3%|▎         | 281523/10000000 [00:00<00:07, 1269169.14it/s]
#
#   4%|▍         | 375182/10000000 [00:00<00:08, 1146813.19it/s]
#
#   5%|▌         | 542856/10000000 [00:00<00:07, 1266933.72it/s]
#
#   7%|▋         | 720204/10000000 [00:00<00:06, 1385666.68it/s]
#
#   9%|▉         | 921665/10000000 [00:00<00:05, 1528853.02it/s]
#
#  11%|█▏        | 1130983/10000000 [00:00<00:05, 1663387.78it/s]
#
#  13%|█▎        | 1335827/10000000 [00:00<00:04, 1762793.63it/s]
#
#  15%|█▌        | 1524802/10000000 [00:00<00:04, 1799051.85it/s]
#
#  17%|█▋        | 1727857/10000000 [00:01<00:04, 1862760.63it/s]
#
#  19%|█▉        | 1938175/10000000 [00:01<00:04, 1928909.32it/s]
#
#  22%|██▏       | 2153988/10000000 [00:01<00:03, 1992392.46it/s]
#
#  24%|██▎       | 2359240/10000000 [00:01<00:03, 2010056.70it/s]
#
#  26%|██▌       | 2563352/10000000 [00:01<00:03, 2019273.67it/s]
#
#  28%|██▊       | 2766243/10000000 [00:01<00:04, 1555697.39it/s]
#
#  30%|██▉       | 2972575/10000000 [00:01<00:04, 1679667.51it/s]
#
#  32%|███▏      | 3173789/10000000 [00:01<00:03, 1767270.45it/s]
#
#  34%|███▎      | 3367106/10000000 [00:01<00:03, 1813970.79it/s]
#
#  36%|███▌      | 3581155/10000000 [00:02<00:03, 1900963.19it/s]
#
#  38%|███▊      | 3799823/10000000 [00:02<00:03, 1978516.52it/s]
#
#  40%|████      | 4018465/10000000 [00:02<00:02, 2036611.95it/s]
#
#  42%|████▏     | 4232166/10000000 [00:02<00:02, 2065724.40it/s]
#
#  44%|████▍     | 4441912/10000000 [00:02<00:02, 2048702.27it/s]
#
#  47%|████▋     | 4657962/10000000 [00:02<00:02, 2081003.83it/s]
#
#  49%|████▉     | 4878755/10000000 [00:02<00:02, 2117521.65it/s]
#
#  51%|█████     | 5098662/10000000 [00:02<00:02, 2141341.57it/s]
#
#  53%|█████▎    | 5313803/10000000 [00:02<00:02, 2142646.57it/s]
#
#  55%|█████▌    | 5528773/10000000 [00:02<00:02, 2117832.85it/s]
#
#  57%|█████▋    | 5741424/10000000 [00:03<00:02, 2120424.62it/s]
#
#  60%|█████▉    | 5955892/10000000 [00:03<00:01, 2127642.52it/s]
#
#  62%|██████▏   | 6168937/10000000 [00:03<00:01, 2101937.61it/s]
#
#  64%|██████▍   | 6379398/10000000 [00:03<00:01, 2095766.04it/s]
#
#  66%|██████▌   | 6589166/10000000 [00:03<00:01, 2081856.69it/s]
#
#  68%|██████▊   | 6801849/10000000 [00:03<00:01, 2095146.82it/s]
#
#  70%|███████   | 7020822/10000000 [00:03<00:01, 2122650.21it/s]
#
#  72%|███████▏  | 7233264/10000000 [00:03<00:01, 2108644.65it/s]
#
#  74%|███████▍  | 7445023/10000000 [00:03<00:01, 2111317.90it/s]
#
#  77%|███████▋  | 7656258/10000000 [00:03<00:01, 2084824.24it/s]
#
#  79%|███████▊  | 7867134/10000000 [00:04<00:01, 2091946.83it/s]
#
#  81%|████████  | 8080623/10000000 [00:04<00:00, 2104646.39it/s]
#
#  83%|████████▎ | 8295568/10000000 [00:04<00:00, 2117889.23it/s]
#
#  85%|████████▌ | 8507799/10000000 [00:04<00:00, 2119211.10it/s]
#
#  87%|████████▋ | 8720059/10000000 [00:04<00:00, 2120225.73it/s]
#
#  89%|████████▉ | 8936323/10000000 [00:04<00:00, 2132773.38it/s]
#
#  91%|█████████▏| 9149648/10000000 [00:04<00:00, 2102119.97it/s]
#
#  94%|█████████▎| 9371336/10000000 [00:04<00:00, 2135278.40it/s]
#
#  96%|█████████▌| 9585084/10000000 [00:04<00:00, 2133168.70it/s]
#
# 100%|██████████| 10000000/10000000 [00:05<00:00, 1990291.46it/s][A
# 10000000
# it took 5.031082391738892

# %%
p = Path('public-covid-data/')
df_list = []
for folder in p.iterdir():
    path_list = [p.as_posix() for p in list(folder.iterdir())]
    file_list = [os.path.split(p)[1] for p in list(folder.iterdir())]
    df_list.append(pd.DataFrame({'path':path_list, 'filename': file_list}))

# %%
df = df_list[1].merge(df_list[2], on='filename', suffixes=('_im', '_msk'))
df
# Out:
#                             path_im  filename  \
# 0  public-covid-data/rp_im/1.nii.gz  1.nii.gz
# 1  public-covid-data/rp_im/2.nii.gz  2.nii.gz
# 2  public-covid-data/rp_im/3.nii.gz  3.nii.gz
# 3  public-covid-data/rp_im/4.nii.gz  4.nii.gz
# 4  public-covid-data/rp_im/5.nii.gz  5.nii.gz
# 5  public-covid-data/rp_im/6.nii.gz  6.nii.gz
# 6  public-covid-data/rp_im/7.nii.gz  7.nii.gz
# 7  public-covid-data/rp_im/8.nii.gz  8.nii.gz
# 8  public-covid-data/rp_im/9.nii.gz  9.nii.gz
#
#                             path_msk
# 0  public-covid-data/rp_msk/1.nii.gz
# 1  public-covid-data/rp_msk/2.nii.gz
# 2  public-covid-data/rp_msk/3.nii.gz
# 3  public-covid-data/rp_msk/4.nii.gz
# 4  public-covid-data/rp_msk/5.nii.gz
# 5  public-covid-data/rp_msk/6.nii.gz
# 6  public-covid-data/rp_msk/7.nii.gz
# 7  public-covid-data/rp_msk/8.nii.gz
# 8  public-covid-data/rp_msk/9.nii.gz

# %%
for idx, row in tqdm(df.iterrows(), total=len(df)):
    print('image path for {} is here {}'.format(row['path_im'], row['filename']))
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 3026.68it/s]
# image path for public-covid-data/rp_im/1.nii.gz is here 1.nii.gz
# image path for public-covid-data/rp_im/2.nii.gz is here 2.nii.gz
# image path for public-covid-data/rp_im/3.nii.gz is here 3.nii.gz
# image path for public-covid-data/rp_im/4.nii.gz is here 4.nii.gz
# image path for public-covid-data/rp_im/5.nii.gz is here 5.nii.gz
# image path for public-covid-data/rp_im/6.nii.gz is here 6.nii.gz
# image path for public-covid-data/rp_im/7.nii.gz is here 7.nii.gz
# image path for public-covid-data/rp_im/8.nii.gz is here 8.nii.gz
# image path for public-covid-data/rp_im/9.nii.gz is here 9.nii.gz

# %%
folder = list(p.iterdir())[1]
[os.path.split(p)[1] for p in list(folder.iterdir())]
# Out:
# ['1.nii.gz',
#  '2.nii.gz',
#  '3.nii.gz',
#  '4.nii.gz',
#  '5.nii.gz',
#  '6.nii.gz',
#  '7.nii.gz',
#  '8.nii.gz',
#  '9.nii.gz']

# %%
sub_p = list(p.iterdir())[1]
list(sub_p.iterdir())
# Out:
# [PosixPath('public-covid-data/rp_im/1.nii.gz'),
#  PosixPath('public-covid-data/rp_im/2.nii.gz'),
#  PosixPath('public-covid-data/rp_im/3.nii.gz'),
#  PosixPath('public-covid-data/rp_im/4.nii.gz'),
#  PosixPath('public-covid-data/rp_im/5.nii.gz'),
#  PosixPath('public-covid-data/rp_im/6.nii.gz'),
#  PosixPath('public-covid-data/rp_im/7.nii.gz'),
#  PosixPath('public-covid-data/rp_im/8.nii.gz'),
#  PosixPath('public-covid-data/rp_im/9.nii.gz')]

# %%
sub_p.as_posix()
# Out:
# 'public-covid-data/new_folder'

# %%
str(sub_p)
# Out:
# 'public-covid-data/new_folder'

# %%
import nibabel as nib

# %%
path_im = df['path_im'].iloc[0]
path_msk = df['path_msk'].iloc[0]
im_nifti = nib.load(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-5b65799db457> in <module>
#       1 path_im = df['path_im'].iloc[0]
#       2 path_msk = df['path_msk'].iloc[0]
# ----> 3 im_nifti = nib.load(path)
#
# NameError: name 'path' is not defined

# %%
def load_nifti(path):
    im_nifti = nib.load(path)
    data = im_nifti.get_fdata()
    data = np.transpose(data)
    
    return data

# %%
data_im = load_nifti(path_im)
data_msk = load_nifti(path_msk)

# %%
data_msk.shape
# Out:
# (45, 630, 630)

# %%
plt.imshow(data_im[20], cmap='gray')

# %%
data = im_nifti.get_fdata()

# %%
data.shape
# Out:
# (630, 630, 45)

# %%
plt.imshow(data[:, :, 24], cmap='gray')

# %%
data_t = np.transpose(data)
data_t.shape
# Out:
# (45, 630, 630)

# %%
plt.imshow(data_t[24, :, :], cmap='gray')

# %%
plt.imshow(data_msk[40], cmap='gray')

# %%
np.unique(data_msk)
# Out:
# array([0., 1., 2.])

# %%
data_msk.shape
# Out:
# (45, 630, 630)

# %%
df['slice_num'] = np.nan

# %%
for idx, row in tqdm(df.iterrows(), total=len(df)):
    data = load_nifti(row['path_im'])
    slice_num = data.shape[0]
    df.loc[idx, 'slice_num'] = slice_num
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
#
#  11%|█         | 1/9 [00:00<00:05,  1.44it/s]
#
#  22%|██▏       | 2/9 [00:01<00:04,  1.67it/s]
#
#  33%|███▎      | 3/9 [00:05<00:11,  1.87s/it]
#
#  44%|████▍     | 4/9 [00:06<00:07,  1.47s/it]
#
#  56%|█████▌    | 5/9 [00:07<00:04,  1.24s/it]
#
#  67%|██████▋   | 6/9 [00:07<00:02,  1.01it/s]
#
#  78%|███████▊  | 7/9 [00:07<00:01,  1.23it/s]
#
#  89%|████████▉ | 8/9 [00:08<00:00,  1.46it/s]
#
# 100%|██████████| 9/9 [00:09<00:00,  1.02s/it]

# %%
df
# Out:
#                             path_im  filename  \
# 0  public-covid-data/rp_im/1.nii.gz  1.nii.gz
# 1  public-covid-data/rp_im/2.nii.gz  2.nii.gz
# 2  public-covid-data/rp_im/3.nii.gz  3.nii.gz
# 3  public-covid-data/rp_im/4.nii.gz  4.nii.gz
# 4  public-covid-data/rp_im/5.nii.gz  5.nii.gz
# 5  public-covid-data/rp_im/6.nii.gz  6.nii.gz
# 6  public-covid-data/rp_im/7.nii.gz  7.nii.gz
# 7  public-covid-data/rp_im/8.nii.gz  8.nii.gz
# 8  public-covid-data/rp_im/9.nii.gz  9.nii.gz
#
#                             path_msk  slice_num
# 0  public-covid-data/rp_msk/1.nii.gz       45.0
# 1  public-covid-data/rp_msk/2.nii.gz       39.0
# 2  public-covid-data/rp_msk/3.nii.gz      418.0
# 3  public-covid-data/rp_msk/4.nii.gz       39.0
# 4  public-covid-data/rp_msk/5.nii.gz       66.0
# 5  public-covid-data/rp_msk/6.nii.gz       42.0
# 6  public-covid-data/rp_msk/7.nii.gz       42.0
# 7  public-covid-data/rp_msk/8.nii.gz       45.0
# 8  public-covid-data/rp_msk/9.nii.gz       93.0

# %%
sns.distplot(df['slice_num'])

# %%
from multiprocessing import Pool, cpu_count
import time

# %%
def square(n):
    return n ** 2

params = [1, 2, 3, 4]
i = map(square, params)

# %%
next(i)
# Out:
# 9

# %%
[square(p) for p in params]
# Out:
# [1, 4, 9, 16]

# %%
cpu_count()
# Out:
# 2

# %%
p = Pool(processes=cpu_count())

def wait_sec(sec):
    time.sleep(sec)
    return sec ** 2

# %%
before = time.time()
results =list(tqdm(p.imap_unordered(wait_sec, [1, 5, 3]), total=3))
# for i in p.imap(wait_sec, [1, 5, 3]):
#     print('{}: {} sec'.format(i, time.time() - before))
after = time.time()
print('it took {} sec'.format(after - before))
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:01,  1.01it/s]
#
#  67%|██████▋   | 2/3 [00:03<00:01,  1.59s/it]
#
# 100%|██████████| 3/3 [00:04<00:00,  1.67s/it]
# it took 5.023375749588013 sec

# %%
results
# Out:
# [1, 25, 9]

# %%
def multiply(a, b):
    return a * b

def wrap_multiply(args):
    return multiply(*args)

param1 = [1, 2, 3, 4]
param2 = [10, 30, 70, 20]
job_args = list(zip(param1, param2))

p = Pool(processes=cpu_count())
results = list(p.imap(wrap_multiply, job_args))
p.close()
p.join()

# %%
results
# Out:
# [10, 60, 210, 80]

# %%
# %load_ext autoreload
# %autoreload 2

# import util
# from フォルダ名.ファイル名 import 関数名
from util import multiply2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
multiply2(3, 2)
# Out:
# 3 * 2 = 6!!!
# 6
